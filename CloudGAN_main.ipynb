# %% [markdown]
# <a href="https://colab.research.google.com/github/hasdasda/BTLcoLan/blob/main/CloudGAN_main.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
tf_upgrade_v2 \
--intree /content/drive/MyDrive/CloudGAN-main/ \
--outtree /content/drive/MyDrive/CloudGAN-main-tf2/ \
--reportfile /content/drive/MyDrive/CloudGAN-main/upgrade_report.txt
# Out:
# 2025-07-08 19:31:10.522437: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752003070.545750   27879 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752003070.552440   27879 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-08 19:31:10.573509: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# !pip install -r /content/drive/MyDrive/CloudGAN-main/requirements.txt
# Out:
# ...
#   Cloning https://github.com/JiahuiYu/neuralgym to /tmp/pip-install-v3z3oa2v/neuralgym_273f894e94e44294adf828f7f268aed5
#   Running command git clone --filter=blob:none --quiet https://github.com/JiahuiYu/neuralgym /tmp/pip-install-v3z3oa2v/neuralgym_273f894e94e44294adf828f7f268aed5
#   Resolved https://github.com/JiahuiYu/neuralgym to commit 88292adb524186693a32404c0cfdc790426ea441
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 7.3/7.3 MB 47.2 MB/s eta 0:00:00
#   Installing build dependencies ... done
#   Getting requirements to build wheel ... done
#   Preparing metadata (pyproject.toml) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 301.1/301.1 kB 18.9 MB/s eta 0:00:00
#   Preparing metadata (setup.py) ... done
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 29.8/29.8 MB 19.6 MB/s eta 0:00:00
#   error: subprocess-exited-with-error
#
#   × python setup.py egg_info did not run successfully.
#   │ exit code: 1
# ...

# %%
# !cd /content/drive/MyDrive/CloudGAN-main

# %%
# !python3 /content/drive/MyDrive/CloudGAN-main/CloudGAN.py \
--img /content/drive/MyDrive/CloudGAN-main/datasets/input_image.jpg \
--target /content/drive/MyDrive/CloudGAN-main/datasets/target_image.png \
--output /content/drive/MyDrive/CloudGAN-main/datasets/output/cleaned_image.png \
--weights_GAN /content/drive/MyDrive/CloudGAN-main/pretrained/SN_PatchGAN \
--config_GAN /content/drive/MyDrive/CloudGAN-main/config/gan_config.yml \
--weights_AE /content/drive/MyDrive/CloudGAN-main/pretrained/AE_checkpointae_checkpoint.h5 \
--config_AE /content/drive/MyDrive/CloudGAN-main/config/ae_config.yml
# Out:
# 2025-07-08 19:33:34.537416: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:477] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# E0000 00:00:1752003214.639989   28792 cuda_dnn.cc:8310] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# E0000 00:00:1752003214.667819   28792 cuda_blas.cc:1418] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2025-07-08 19:33:34.845447: I tensorflow/core/platform/cpu_feature_guard.cc:210] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: AVX2 FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.
# ...

# %%
# import os

# base_path = '/content/drive/MyDrive'

# keep_items = [
#     'Mindmap.drawio',
#     'model_20.pth',
#     'output_gray.jpg',
#     'Colab Notebooks',
#     'Data',
#     'Data01',
#     'Datakhac',
#     'Datathoitiet',
#     'Datathu',
#     'Document-Classifier-LSTM-master',
#     'pretrain',
#     'Vid',
#     'VNPT',
#     'Phạm Trung Hiếu - 20207560.docx'
# ]

# for item in keep_items:
#     item_path = os.path.join(base_path, item)
#     if os.path.exists(item_path):
#         print(f'✅ Tồn tại: {item}')
#     else:
#         print(f'❌ Không tồn tại: {item}')
# Out:
# ✅ Tồn tại: Mindmap.drawio
# ✅ Tồn tại: model_20.pth
# ✅ Tồn tại: output_gray.jpg
# ✅ Tồn tại: Colab Notebooks
# ✅ Tồn tại: Data
# ✅ Tồn tại: Data01
# ✅ Tồn tại: Datakhac
# ✅ Tồn tại: Datathoitiet
# ✅ Tồn tại: Datathu
# ✅ Tồn tại: Document-Classifier-LSTM-master
# ✅ Tồn tại: pretrain
# ✅ Tồn tại: Vid
# ✅ Tồn tại: VNPT
# ✅ Tồn tại: Phạm Trung Hiếu - 20207560.docx

# %%
# import os
# import shutil

# base_path = '/content/drive/MyDrive'

# keep_items = [
#     'Mindmap.drawio',
#     'model_20.pth',
#     'output_gray.jpg',
#     'Colab Notebooks',
#     'Data',
#     'Data01',
#     'Datakhac',
#     'Datathoitiet',
#     'Datathu',
#     'Document-Classifier-LSTM-master',
#     'pretrain',
#     'Vid',
#     'VNPT',
#     'Phạm Trung Hiếu - 20207560.docx'
# ]

# # Quét tất cả file & thư mục hiện có
# all_items = os.listdir(base_path)

# # Xóa tất cả những gì KHÔNG thuộc keep_items
# for item in all_items:
#     if item not in keep_items:
#         item_path = os.path.join(base_path, item)
#         try:
#             if os.path.isdir(item_path):
#                 shutil.rmtree(item_path)
#                 print(f'🗑️ Đã xóa thư mục: {item}')
#             else:
#                 os.remove(item_path)
#                 print(f'🗑️ Đã xóa tệp: {item}')
#         except Exception as e:
#             print(f'⚠️ Lỗi khi xóa {item}: {e}')

# print("\n✅ Đã hoàn tất xóa các file không cần thiết.")
# Out:
# Kết quả truyền trực tuyến bị cắt bớt đến 5000 dòng cuối.
# 🗑️ Đã xóa tệp: PMC5029805_7.xml
# 🗑️ Đã xóa tệp: PMC5029805_8.xml
# 🗑️ Đã xóa tệp: PMC5029805_9.xml
# 🗑️ Đã xóa tệp: PMC5029814_3.xml
# 🗑️ Đã xóa tệp: PMC5029814_4.xml
# 🗑️ Đã xóa tệp: PMC5029814_5.xml
# 🗑️ Đã xóa tệp: PMC5029814_6.xml
# 🗑️ Đã xóa tệp: PMC5029814_7.xml
# 🗑️ Đã xóa tệp: PMC5029866_11.xml
# 🗑️ Đã xóa tệp: PMC5029866_8.xml
# 🗑️ Đã xóa tệp: PMC5029912_5.xml
# 🗑️ Đã xóa tệp: PMC5030088_1.xml
# 🗑️ Đã xóa tệp: PMC5030206_3.xml
# 🗑️ Đã xóa tệp: PMC5030206_5.xml
# 🗑️ Đã xóa tệp: PMC5030218_2.xml
# 🗑️ Đã xóa tệp: PMC5030218_4.xml
# 🗑️ Đã xóa tệp: PMC5030236_6.xml
# 🗑️ Đã xóa tệp: PMC5030308_2.xml
# 🗑️ Đã xóa tệp: PMC5030568_3.xml
# 🗑️ Đã xóa tệp: PMC5030607_3.xml
# 🗑️ Đã xóa tệp: PMC5030607_4.xml
# 🗑️ Đã xóa tệp: PMC5030607_5.xml
# 🗑️ Đã xóa tệp: PMC5030733_10.xml
# 🗑️ Đã xóa tệp: PMC5030733_11.xml
# 🗑️ Đã xóa tệp: PMC5030733_2.xml
# 🗑️ Đã xóa tệp: PMC5030733_3.xml
# 🗑️ Đã xóa tệp: PMC5030733_7.xml
# ...
